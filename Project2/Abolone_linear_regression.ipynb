# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

data = pd.read_csv("Abalone.csv" , header= None)

# %%
data.head()
# Out:
#    0      1      2      3       4       5       6      7   8
# 0  M  0.455  0.365  0.095  0.5140  0.2245  0.1010  0.150  15
# 1  M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.070   7
# 2  F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.210   9
# 3  M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.155  10
# 4  I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.055   7

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4177 non-null   object
#  1   1       4177 non-null   float64
#  2   2       4177 non-null   float64
#  3   3       4177 non-null   float64
#  4   4       4177 non-null   float64
#  5   5       4177 non-null   float64
#  6   6       4177 non-null   float64
#  7   7       4177 non-null   float64
#  8   8       4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
data.iloc[:,0] = data.iloc[:,0].map({"I" : 0, "F": 1, "M": 2})

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4177 non-null   int64
#  1   1       4177 non-null   float64
#  2   2       4177 non-null   float64
#  3   3       4177 non-null   float64
#  4   4       4177 non-null   float64
#  5   5       4177 non-null   float64
#  6   6       4177 non-null   float64
#  7   7       4177 non-null   float64
#  8   8       4177 non-null   int64
# dtypes: float64(7), int64(2)
# memory usage: 293.8 KB

# %%
### Exploring the PDFs

# %%
from sklearn.feature_selection import f_regression

f_regression(data.iloc[:, 1:-1] , data.iloc[:, -1])
# Out:
# (array([1875.16948936, 2058.51984918, 1882.48283818, 1722.06759276,
#          898.78593313, 1420.26845117, 2712.72475677]),
#  array([0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 1.88867822e-315,
#         5.08746422e-179, 8.57472644e-268, 0.00000000e+000]))

# %%
# p_value

f_regression(data.iloc[:, 1:-1] , data.iloc[:, -1])[1].round(10)
# Out:
# array([0., 0., 0., 0., 0., 0., 0.])

# %%
#dealing with outliers(98%)

sns.displot(data.iloc[:, 1])

# %%
q = data.iloc[:, 1].quantile(0.02)
data_1 = data[data.iloc[:, 1] > q]

# %%
sns.displot(data_1.iloc[:, 1])

# %%
sns.displot(data.iloc[:, 2])

# %%
q = data_1.iloc[:, 2].quantile(0.02)
data_2 = data_1[data_1.iloc[:, 2] > q]

# %%
sns.displot(data_2.iloc[:, 2])

# %%
sns.displot(data.iloc[:, 3])

# %%
#q = data_2.iloc[:, 3].quantile(0.99 )
data_3 = data_2[ data_2.iloc[:, 3] < 0.3]

# %%
sns.displot(data_3.iloc[:, 3])

# %%
#q = data_3.iloc[:, 3].quantile(0.005 )
data_33 = data_3[ data_3.iloc[:, 3] > 0.05]

# %%
sns.displot(data_33.iloc[:, 3])

# %%
sns.displot(data.iloc[:,4])

# %%
q = data_33.iloc[:, 4].quantile(0.98)
data_4 = data_33[ data_33.iloc[:, 4] < q]

# %%
sns.displot(data_4.iloc[:,4])

# %%
sns.displot(data.iloc[:, 5])

# %%
q = data_4.iloc[:, 5].quantile(0.98)
data_5 = data_4[ data_4.iloc[:, 5] < q]

# %%
sns.displot(data_5.iloc[:, 5])

# %%
sns.displot(data.iloc[:, 6])

# %%
q = data_5.iloc[:, 6].quantile(0.98)
data_6 = data_5[ data_5.iloc[:, 6] < q]

# %%
sns.displot(data_6.iloc[:, 6])

# %%
sns.displot(data.iloc[:, 7])

# %%
q = data_6.iloc[:, 7].quantile(0.98)
data_7 = data_6[ data_6.iloc[:, 7] < q]

# %%
sns.displot(data_7.iloc[:, 7])

# %%
# year
sns.displot(data.iloc[:, 8])

# %%
#q = data_7.iloc[:, 8].quantile(0.98)
#data_8 = data_7[ data_7.iloc[:, 8] < q]

# %%
#sns.displot(data_8.iloc[:, 8])

# %%
data_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3686 entries, 0 to 4175
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3686 non-null   int64
#  1   1       3686 non-null   float64
#  2   2       3686 non-null   float64
#  3   3       3686 non-null   float64
#  4   4       3686 non-null   float64
#  5   5       3686 non-null   float64
#  6   6       3686 non-null   float64
#  7   7       3686 non-null   float64
#  8   8       3686 non-null   int64
# dtypes: float64(7), int64(2)
# memory usage: 288.0 KB

# %%
data_cleaned = data_7.reset_index(drop = True)

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3686 entries, 0 to 3685
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3686 non-null   int64
#  1   1       3686 non-null   float64
#  2   2       3686 non-null   float64
#  3   3       3686 non-null   float64
#  4   4       3686 non-null   float64
#  5   5       3686 non-null   float64
#  6   6       3686 non-null   float64
#  7   7       3686 non-null   float64
#  8   8       3686 non-null   int64
# dtypes: float64(7), int64(2)
# memory usage: 259.3 KB

# %%
#Checking the OLS assumptions

f, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(7, 1, sharey=True, figsize =(10,40))
ax1.scatter(data_cleaned.iloc[:, 1],data_cleaned.iloc[:, -1])
ax1.set_title('Year , 1')
ax2.scatter(data_cleaned.iloc[:, 2],data_cleaned.iloc[:, -1])
ax2.set_title('Year , 2')
ax3.scatter(data_cleaned.iloc[:, 3],data_cleaned.iloc[:, -1])
ax3.set_title('Year , 3')
ax4.scatter(data_cleaned.iloc[:, 4],data_cleaned.iloc[:, -1])
ax4.set_title('Year , 4')
ax5.scatter(data_cleaned.iloc[:, 5],data_cleaned.iloc[:, -1])
ax5.set_title('Year , 5')
ax6.scatter(data_cleaned.iloc[:, 6],data_cleaned.iloc[:, -1])
ax6.set_title('Year , 6')
ax7.scatter(data_cleaned.iloc[:, 7],data_cleaned.iloc[:, -1])
ax7.set_title('Year , 7')

plt.show()

# %%
log_year = np.log(data_cleaned.iloc[:, -1])
data_cleaned.iloc[:, -1] = log_year 


log_year = np.log(data_cleaned.iloc[:, 1])
data_cleaned.iloc[:, 1] = log_year 



log_year = np.log(data_cleaned.iloc[:, 2])
data_cleaned.iloc[:, 2] = log_year 



log_year = np.log(data_cleaned.iloc[:, 3])
data_cleaned.iloc[:, 3] = log_year 

log_year = np.log(data_cleaned.iloc[:, 4])
data_cleaned.iloc[:, 4] = log_year 


log_year = np.log(data_cleaned.iloc[:, 5])
data_cleaned.iloc[:, 5] = log_year 


log_year = np.log(data_cleaned.iloc[:, 6])
data_cleaned.iloc[:, 6] = log_year 


log_year = np.log(data_cleaned.iloc[:, 7])
data_cleaned.iloc[:, 7] = log_year 


data_cleaned
# Out:
#       0         1         2         3         4         5         6         7  \
# 0     2 -0.787458 -1.007858 -2.353878 -0.665532 -1.493880 -2.292635 -1.897120
# 1     2 -1.049822 -1.328025 -2.407946 -1.489435 -2.307598 -3.026191 -2.659260
# 2     1 -0.634878 -0.867501 -2.002481 -0.390084 -1.360627 -1.955456 -1.560648
# 3     2 -0.820981 -1.007858 -2.079442 -0.661649 -1.534794 -2.171557 -1.864330
# 4     0 -1.108663 -1.366492 -2.525729 -1.584745 -2.413517 -3.231455 -2.900422
# ...  ..       ...       ...       ...       ...       ...       ...       ...
# 3681  2 -0.579818 -0.843970 -1.864330 -0.142140 -0.916291 -1.760261 -1.474033
# 3682  1 -0.570930 -0.798508 -1.801810 -0.119910 -0.994252 -1.431292 -1.390302
# 3683  2 -0.527633 -0.820981 -2.002481 -0.034591 -0.823256 -1.539446 -1.345152
# 3684  2 -0.510826 -0.744440 -1.584745  0.162119 -0.643405 -1.246532 -1.177655
# 3685  1 -0.470004 -0.723606 -1.897120  0.090298 -0.632993 -1.343235 -1.217396
#
#              8
# 0     2.708050
# ...

# %%
#Checking the OLS assumptions

f, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(7, 1, sharey=True, figsize =(10,40))
ax1.scatter(data_cleaned.iloc[:, 1],data_cleaned.iloc[:, -1])
ax1.set_title('Year , 1')
ax2.scatter(data_cleaned.iloc[:, 2],data_cleaned.iloc[:, -1])
ax2.set_title('Year , 2')
ax3.scatter(data_cleaned.iloc[:, 3],data_cleaned.iloc[:, -1])
ax3.set_title('Year , 3')
ax4.scatter(data_cleaned.iloc[:, 4],data_cleaned.iloc[:, -1])
ax4.set_title('Year , 4')
ax5.scatter(data_cleaned.iloc[:, 5],data_cleaned.iloc[:, -1])
ax5.set_title('Year , 5')
ax6.scatter(data_cleaned.iloc[:, 6],data_cleaned.iloc[:, -1])
ax6.set_title('Year , 6')
ax7.scatter(data_cleaned.iloc[:, 7],data_cleaned.iloc[:, -1])
ax7.set_title('Year , 7')

plt.show()

# %%
#Multicollinearity

from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = data_cleaned.iloc[:,1:-1]
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif["features"] = variables.columns

vif
# Out:
#           VIF  features
# 0  488.028733         1
# 1  690.336166         2
# 2  297.593413         3
# 3   64.541007         4
# 4  127.833022         5
# 5  180.508261         6
# 6  249.772156         7

# %%
#Linear regression model

inputs = data_cleaned.iloc[:,:-1]
target = data_cleaned.iloc[:,-1]

# %%
#Scale the data

from sklearn.preprocessing import StandardScaler

scaler =StandardScaler()
scaler.fit(inputs)
scaled_features = scaler.transform(inputs)

# %%
import statsmodels.api as sm

x = sm.add_constant(scaled_features)
y = data_cleaned.iloc[:,-1]
model = sm.OLS(y, x).fit()

#view model summary
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      8   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     547.3
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):               0.00
# Time:                        18:54:17   Log-Likelihood:                 908.57
# No. Observations:                3686   AIC:                            -1799.
# Df Residuals:                    3677   BIC:                            -1743.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2545      0.003    722.921      0.000       2.248       2.261
# ...

# %%
# Prob (F-statistic) < 0.000 => the overal model is significant
# P_value for X3 > 0.000 => will remove.
# Durbin-Watson falls between 1 and 3 => No Auto correlation between errors.

scaled_features =pd.DataFrame(scaled_features).drop([2], axis = 1)
scaled_features
# Out:
#              0         1         3         4         5         6         7
# 0     1.155089 -0.591638 -1.379392 -0.398050 -0.354524 -0.530929 -0.412125
# 1     1.155089 -1.881710 -1.594917 -1.701396 -1.598987 -1.658377 -1.661533
# 2    -0.051388  0.158611  0.021369  0.037685 -0.150733 -0.012698  0.139468
# 3     1.155089 -0.756473 -0.285417 -0.391907 -0.417097 -0.344837 -0.358372
# 4    -1.257865 -2.171035 -2.064430 -1.852169 -1.760974 -1.973859 -2.056880
# ...        ...       ...       ...       ...       ...       ...       ...
# 3681  1.155089  0.429346  0.572071  0.429912  0.528814  0.287308  0.281458
# 3682 -0.051388  0.473054  0.821293  0.465077  0.409583  0.792921  0.418722
# 3683  1.155089  0.685949  0.021369  0.600045  0.671097  0.626693  0.492738
# 3684  1.155089  0.768591  1.686567  0.911224  0.946153  1.076889  0.767323
# 3685 -0.051388  0.969317  0.441362  0.797609  0.962076  0.928261  0.702175
#
# [3686 rows x 7 columns]

# %%
#Train Test Split

from sklearn.model_selection import train_test_split

x_train ,x_test , y_train , y_test = train_test_split(scaled_features, target ,test_size= 0.3 , random_state=42 )

# %%
#Create the regression

from sklearn.linear_model import LinearRegression

reg = LinearRegression()

reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_hat = reg.predict(x_train)

# %%
plt.scatter(y_train , y_hat)
plt.xlabel("target(y_train)", size =18)
plt.ylabel("prediction(y_hat)" , size =18)

plt.show()

# %%
sns.displot(y_hat-y_train)
plt.title("Residuals PDF", size=18)
# Out:
# Text(0.5, 1.0, 'Residuals PDF')

# %%
# R2 score
reg.score(x_train, y_train)
# Out:
# 0.5451166762939117

# %%
from sklearn.metrics import mean_squared_error

y_pred = reg.predict(x_test)

mean_squared_error(y_test , y_pred)
# Out:
# 0.03590150551898356

# %%
from sklearn.preprocessing import PolynomialFeatures

polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(x_train)
x_poly_test = polynomial_features.fit_transform(x_test)
model = LinearRegression()
model.fit(x_poly, y_train)
y_predicted3 = model.predict(x_poly_test)

# %%
mean_squared_error(y_test , y_predicted3)
# Out:
# 0.034573279809730635
